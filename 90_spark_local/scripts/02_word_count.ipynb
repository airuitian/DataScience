# %% [markdown]
# # 使用Jupyter 统计文本中单词出现的个数
# ## 1. 导入pyspark包

# %%
from pyspark import SparkContext

# %% [markdown]
# ## 2. 创建SparkContext

# %%
sc = SparkContext('local', 'Wordcount')

# %%
textFile = sc.textFile('./data/words')
word_count = textFile.flatMap(lambda line: line.split(" "))\
                     .map(lambda word: (word,1))\
                     .reduceByKey(lambda a, b : a + b)

# %%
# foreach会打印到后台
#word_count.foreach(print)
word_count.collect()
# Out:
# [('Path:', 1),
#  ('cantaloupe', 1),
#  ('srv', 1),
#  ('cs', 1),
#  ('cmu', 3),
#  ('edu!magnesium', 1),
#  ('club', 1),
#  ('cc', 1),
#  ('edu!news', 1),
#  ('sei', 1),
#  ('edu!cis', 1),
#  ('ohio-state', 3),
#  ('edu!pacific', 1),
#  ('mps', 2),
#  ('edu!zaphod', 1),
#  ('edu!howland', 1),
#  ('reston', 1),
#  ('ans', 1),
#  ('net!sol', 1),
#  ('ctr', 1),
#  ('columbia', 1),
#  ('edu!destroyer!newsrelay', 1),
#  ('iastate', 1),
#  ('edu!iscsvax', 1),
#  ('uni', 1),
#  ('edu!sunfish!pwiseman', 1),
#  ('Newsgroups:', 1),
#  ('comp', 1),
#  ('os', 1),
#  ('ms-windows', 1),
#  ('misc', 1),
#  ('Subject:', 1),
#  ('roman', 1),
#  ('bmp', 1),
#  ('01/14In', 1),
#  ('response', 1),
#  ('to', 8),
#  ('the', 9),
#  ('requests', 1),
#  ('for', 3),
#  ('cool', 1),
#  ('bitmaps', 1),
#  ('I', 3),
#  ('am', 1),
#  ('posting', 1),
#  ('one', 1),
#  ('', 26),
#  ('Message-ID:', 1),
#  ('<C65FzK', 1),
#  ('1M2@sunfish', 1),
#  ('usd', 4),
#  ('edu>', 1),
#  ('From:', 1),
#  ('pwiseman@salmon', 2),
#  ('edu', 3),
#  ('(Cliff)', 3),
#  ('Date:', 1),
#  ('Tue,', 1),
#  ('27', 1),
#  ('Apr', 1),
#  ('1993', 1),
#  ('15:50:05', 1),
#  ('GMT', 1),
#  ('Reply-To:', 1),
#  ('Sender:', 1),
#  ('pwiseman@sunfish', 1),
#  ('Distribution:', 1),
#  ('usa', 1),
#  ('Organization:', 1),
#  ('University', 1),
#  ('of', 3),
#  ('South', 1),
#  ('Dakota', 1),
#  ('Lines:', 1),
#  ('978', 1),
#  ('Due', 1),
#  ('resolution', 2),
#  ('and', 4),
#  ('size', 2),
#  ('it', 3),
#  ('is', 5),
#  ('in', 3),
#  ('14', 3),
#  ('parts', 3),
#  ('This', 1),
#  ('a', 7),
#  ('uuencoded', 1),
#  ('bitmap', 1),
#  ('960X600', 1),
#  ('256', 1),
#  ('colors', 1),
#  ('The', 2),
#  ('picture', 2),
#  ('marbled', 1),
#  ('gazebo', 1),
#  ('on', 3),
#  ('desert', 1),
#  ('with', 2),
#  ('blue', 1),
#  ('sky', 1),
#  ('background', 1),
#  ('just', 2),
#  ('right', 1),
#  ('centered', 1),
#  ('wallpaper', 2),
#  ('1024x768', 1),
#  ('display', 1),
#  ('because', 1),
#  ('leaves', 1),
#  ('border', 1),
#  ('at', 1),
#  ('bottom', 1),
#  ('big', 1),
#  ('enough', 1),
#  ('icons', 1),
#  ('fit', 1),
#  ('without', 2),
#  ('being', 1),
#  ('top', 1),
#  ('Reguarding', 1),
#  ('image', 2),
#  ('quality', 1),
#  ('-', 1),
#  ('have', 1),
#  ('not', 1),
#  ('seen', 1),
#  ('much', 1),
#  ('better', 1),
#  ('For', 1),
#  ('those', 1),
#  ('you', 1),
#  ('who', 1),
#  ("haven't", 1),
#  ('worked', 1),
#  ('pieced', 1),
#  ('files,', 1),
#  ('here', 1),
#  ('how', 1),
#  ('put', 1),
#  ('back', 1),
#  ('together', 1),
#  ('\t1', 1),
#  ('save', 1),
#  ('individual', 1),
#  ('files', 1),
#  ('\t2', 1),
#  ('use', 1),
#  ('text', 1),
#  ('editor', 1),
#  ('remove', 1),
#  ('header', 1),
#  ('footer', 1),
#  ('\t', 1),
#  ('each', 1),
#  ('file', 3),
#  ('\t3', 1),
#  ('concatinate', 1),
#  ('all', 1),
#  ('into', 1),
#  ('single', 1),
#  ('\t4', 1),
#  ('uudecode', 1),
#  ('There', 1),
#  ('are', 1),
#  ('tools', 2),
#  ('available', 1),
#  ('do', 1),
#  ('this', 1),
#  ('hassle', 1),
#  ('such', 1),
#  ('as', 1),
#  ('uuconvert', 1),
#  ('(UNIX)', 1),
#  ('UUcoder', 1),
#  ('(Windows)', 1),
#  ('If', 1),
#  ('neccesary', 1),
#  ('could', 1),
#  ('post', 1),
#  ('these', 1),
#  ('or', 1),
#  ('where', 1),
#  ('get', 1),
#  ('them', 1),
#  ('by', 1),
#  ('FTP', 1),
#  ('--', 1),
#  ('let', 1),
#  ('me', 1),
#  ('know', 1),
#  ('Keywords:', 1),
#  ('bitmap,', 1)]
